# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("covid19_Confirmed_dataset.csv")

# %%
data1.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
data1.drop(["Lat","Long"],axis=1,inplace=True)

# %%
data2=data1.groupby("Country/Region").sum()

# %%
data2.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
data2.shape
# Out:
# (187, 100)

# %%
plt.figure(figsize=(40,20))
for i in range(187):
    data2.iloc[i].plot()
plt.legend()
plt.xlabel("time line")
plt.ylabel("no. of cases")
plt.show()

# %%
data2.iloc[0].diff().plot()

# %%
data2.iloc[0].diff().max()
# Out:
# 232.0

# %%
data2.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
data2.loc["Spain"].diff().max()
# Out:
# 9630.0

# %%
countries=list(data2.index)
max_inflection=[]
for i in countries:
    max_inflection.append(data2.loc[i].diff().max())
max_inflection
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
data2["max_inflection"]=max_inflection

# %%
data3=pd.DataFrame(data2["max_inflection"])
data3.head()
# Out:
#                 max_inflection
# Country/Region
# Afghanistan              232.0
# Albania                   34.0
# Algeria                  199.0
# Andorra                   43.0
# Angola                     5.0

# %%
data4=pd.read_csv("worldwide_happiness_report.csv")
data4.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
useless_cols=["Overall rank","Score","Generosity",'Perceptions of corruption']

# %%
data4.drop(useless_cols,axis=1,inplace=True)
data4.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
data4.set_index('Country or region',inplace=True)
data4.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
data5=data3.join(data4,how="inner")
data5.head()
# Out:
#              max_inflection  GDP per capita  Social support  \
# Afghanistan           232.0           0.350           0.517
# Albania                34.0           0.947           0.848
# Algeria               199.0           1.002           1.160
# Argentina             291.0           1.092           1.432
# Armenia               134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
data5.corr()
# Out:
#                               max_inflection  GDP per capita  Social support  \
# max_inflection                      1.000000        0.250118        0.191958
# GDP per capita                      0.250118        1.000000        0.759468
# Social support                      0.191958        0.759468        1.000000
# Healthy life expectancy             0.289263        0.863062        0.765286
# Freedom to make life choices        0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_inflection                               0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_inflection                                    0.078196
# ...

# %%
sns.heatmap(data5.corr(),annot=True)

# %%
x=data5['GDP per capita']
y=data5["max_inflection"]
sns.scatterplot(x,y)

# %%
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
data5.head(2)
# Out:
#              max_inflection  GDP per capita  Social support  \
# Afghanistan           232.0           0.350           0.517
# Albania                34.0           0.947           0.848
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
