# %% [markdown]
# # plotting of graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib notebook
g=nx.Graph()
g.add_edges_from([("as","da"),("a","hd"),("a","sk"),("a","ssv"),("a","ps"),("a",'ap'),("a","sg"),("br","pb"),("mp","sp"),("mp","md"),("hd","ka"),("hd","sp"),("hd","md"),("hd","dp"),("ap","mp"),("ssv","mp"),("ps","mp"),("mp","sg"),("ap","sk"),("ssv","sk"),("ps","sk"),("sk","sg"),("ssv","sg"),("ps","sg"),("ap","ssv"),("ssv","ps"),("ps","ap"),("ka","mp"),("mp","dp"),("ka","dp"),("ka","sp"),("sp","md"),("md","ka"),("dp","md"),("dp","sp"),("ar","br"),("hm","ss"),("da","hm"),("sm","ak"),("gk","as"),("as","sm"),("sm","ss"),("ss","da"),("ss","sk"),("sk","da"),("ag","sm"),("pb","sm"),("pb","da"),("br","da"),("ak","ag"),("pb","ak"),("br","hm"),("hm","ar"),("br","ss"),("sk","hd"),("ss","br"),("sm","da"),("ss","hd"),("da","hd"),("da","ak"),("mp","sk"),("mp","hd"),("mp","ss"),("mp","da"),("ss","k"),("mp","k"),("a","mp"),("a","k"),("a","sk"),("hd","a")])
nx.draw_networkx(g);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # clustering coefficient is a measure of the degree to which nodes in a graph tend to cluster together. this tells the extend to which ur friends are friends among each other as well , extent of group formation around a person.

# %%
nx.average_clustering(g)
# Out:
# 0.6894154456654457

# %% [markdown]
# # transitivity is the equal to # ofclosed triads / # of open traids , its like clustering coefficient but gives high weightage to high degree nodes (degree of a node is no. of nodes it is connected to). If u dont know what a traid is fuck off.

# %%
nx.transitivity(g)
# Out:
# 0.5703703703703704

# %% [markdown]
# # tells extent of clustering for each person

# %%
for i in set(nx.nodes(g)):
    print(nx.clustering(g,i),i)
# Out:
# 0.6071428571428571 a
# 0 gk
# 0.5833333333333334 sk
# 1.0 ap
# 1.0 md
# 0.6666666666666666 pb
# 0.6666666666666666 ak
# 0.6666666666666666 k
# 0.3626373626373626 mp
# 1.0 ag
# 0.5 br
# 1.0 ka
# 1.0 ar
# 0.3333333333333333 da
# 0.3333333333333333 as
# 0.5 hd
# 0.4 sm
# 0.6666666666666666 hm
# 1.0 sg
# 0.39285714285714285 ss
# 0.9333333333333333 ps
# 1.0 dp
# 0.9333333333333333 ssv
# 1.0 sp

# %% [markdown]
# # tells the shortest path between any 2 nodes

# %%
sorted(nx.all_shortest_paths(g,"mp","br"))
# Out:
# [['mp', 'da', 'br'], ['mp', 'ss', 'br']]

# %% [markdown]
# # for a particular node , it tells the distance from that node to every other node ie. path length to every other node.

# %%
t=nx.bfs_tree(g,"da")
t.edges()
nx.shortest_path_length(g,"da")
# Out:
# {'da': 0,
#  'as': 1,
#  'hm': 1,
#  'ss': 1,
#  'sk': 1,
#  'pb': 1,
#  'br': 1,
#  'sm': 1,
#  'hd': 1,
#  'ak': 1,
#  'mp': 1,
#  'gk': 2,
#  'ar': 2,
#  'k': 2,
#  'a': 2,
#  'ap': 2,
#  'ssv': 2,
#  'ps': 2,
#  'sg': 2,
#  'ag': 2,
#  'ka': 2,
#  'sp': 2,
#  'md': 2,
#  'dp': 2}

# %% [markdown]
# # average of all path lengths from every node to every other node

# %%
nx.average_shortest_path_length(g)
# Out:
# 2.260869565217391

# %%
print(nx.eccentricity(g))
print(nx.diameter(g))
print(nx.radius(g))
# Out:
# {'as': 3, 'da': 2, 'a': 4, 'hd': 3, 'sk': 3, 'ssv': 4, 'ps': 4, 'ap': 4, 'sg': 4, 'br': 3, 'pb': 3, 'mp': 3, 'sp': 4, 'md': 4, 'ka': 4, 'dp': 4, 'ar': 4, 'hm': 3, 'ss': 3, 'sm': 3, 'ak': 3, 'gk': 4, 'ag': 4, 'k': 4}
# 4
# 2

# %% [markdown]
# # periphery nodes for given graph

# %%
nx.periphery(g)
# Out:
# ['a', 'ssv', 'ps', 'ap', 'sg', 'sp', 'md', 'ka', 'dp', 'ar', 'gk', 'ag', 'k']

# %% [markdown]
# # center parts of graph

# %%
nx.center(g)
# Out:
# ['da']

# %%
nx.node_connectivity(g)
# Out:
# 1

# %% [markdown]
# # the person if removed , the graph will break into connected graph of 2 components.

# %%
nx.minimum_node_cut(g)
# Out:
# {'as'}

# %%
nx.edge_connectivity(g)
# Out:
# 1

# %%
nx.minimum_edge_cut(g)
# Out:
# {('gk', 'as')}

# %%
sorted(nx.all_shortest_paths(g,"mp","br"))
# Out:
# [['mp', 'da', 'br'], ['mp', 'ss', 'br']]

# %% [markdown]
# # a more accurate study can be done if your social media and chatting data is also used .

# %%
g.edges("a")
# Out:
# EdgeDataView([('a', 'hd'), ('a', 'sk'), ('a', 'ssv'), ('a', 'ps'), ('a', 'ap'), ('a', 'sg'), ('a', 'mp'), ('a', 'k')])

# %% [markdown]
# # as lowest lcc, but for gk data is not sufficient.(lcc=local clustering coeffecient).
# # da , sm and ss have considerable low lcc ,shows their lack of intent for clique formation officially labelling them as ssd.
# # I shall not comment about others.

# %% [markdown]
# the ssd , the ssd thats the the sach ,theres suts and sach the ssd --official theme music

# %% [markdown]
# # data visualization

# %%
plt.figure()
nx.draw_networkx(g)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
[x for x in nx.__dir__() if x.endswith("_layout")]
# Out:
# ['bipartite_layout',
#  'circular_layout',
#  'kamada_kawai_layout',
#  'random_layout',
#  'rescale_layout',
#  'shell_layout',
#  'spring_layout',
#  'spectral_layout',
#  'planar_layout',
#  'fruchterman_reingold_layout']

# %%
plt.figure()
pos=nx.fruchterman_reingold_layout(g)
nx.draw_networkx(g,pos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
pos=nx.kamada_kawai_layout(g)
nx.draw_networkx(g,pos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
pos=nx.spectral_layout(g)
nx.draw_networkx(g,pos)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(g,alpha=0.7,with_label=False,edge_color="0.3")
plt.axis("off")
plt.tight_layout();
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # centrality analysis: centrality tells the importance of a node in a network,there are multiple ways of determining.

# %%
degcent=sorted([i for i in nx.degree_centrality(g).values() ],reverse=True)
deg_cent=nx.degree_centrality(g)
print(degcent)
deg_cent
# Out:
# [0.6086956521739131, 0.43478260869565216, 0.3913043478260869, 0.3913043478260869, 0.34782608695652173, 0.34782608695652173, 0.2608695652173913, 0.2608695652173913, 0.2608695652173913, 0.21739130434782608, 0.21739130434782608, 0.21739130434782608, 0.21739130434782608, 0.21739130434782608, 0.21739130434782608, 0.21739130434782608, 0.17391304347826086, 0.17391304347826086, 0.17391304347826086, 0.13043478260869565, 0.13043478260869565, 0.08695652173913043, 0.08695652173913043, 0.043478260869565216]
# {'as': 0.13043478260869565,
#  'da': 0.43478260869565216,
#  'a': 0.34782608695652173,
#  'hd': 0.3913043478260869,
#  'sk': 0.3913043478260869,
#  'ssv': 0.2608695652173913,
#  'ps': 0.2608695652173913,
#  'ap': 0.21739130434782608,
#  'sg': 0.21739130434782608,
#  'br': 0.21739130434782608,
#  'pb': 0.17391304347826086,
#  'mp': 0.6086956521739131,
#  'sp': 0.21739130434782608,
#  'md': 0.21739130434782608,
#  'ka': 0.21739130434782608,
#  'dp': 0.21739130434782608,
# ...

# %%
closecent=nx.closeness_centrality(g)
import operator
sorted(closecent.items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('mp', 0.6571428571428571),
#  ('da', 0.6388888888888888),
#  ('ss', 0.5897435897435898),
#  ('hd', 0.575),
#  ('sk', 0.575),
#  ('a', 0.46),
#  ('sm', 0.46),
#  ('k', 0.46),
#  ('ssv', 0.4423076923076923),
#  ('ps', 0.4423076923076923),
#  ('br', 0.4423076923076923),
#  ('ap', 0.4339622641509434),
#  ('sg', 0.4339622641509434),
#  ('pb', 0.4339622641509434),
#  ('sp', 0.4339622641509434),
#  ('md', 0.4339622641509434),
#  ('ka', 0.4339622641509434),
#  ('dp', 0.4339622641509434),
#  ('hm', 0.4339622641509434),
#  ('as', 0.42592592592592593),
#  ('ak', 0.42592592592592593),
#  ('ag', 0.323943661971831),
#  ('ar', 0.3150684931506849),
#  ('gk', 0.3026315789473684)]

# %%
import operator
btwn_cent=nx.betweenness_centrality(g,normalized=True,endpoints=False)
btwn_cent_approx=nx.betweenness_centrality(g,normalized=True,endpoints=False,k=2)
sorted(btwn_cent.items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('da', 0.3851684547336721),
#  ('mp', 0.305571240353849),
#  ('ss', 0.15527950310559005),
#  ('hd', 0.11604554865424431),
#  ('sk', 0.10629587803500846),
#  ('as', 0.08695652173913043),
#  ('sm', 0.0790843214756258),
#  ('br', 0.04930830039525692),
#  ('hm', 0.037977602108036884),
#  ('ak', 0.024011857707509878),
#  ('a', 0.016600790513833986),
#  ('pb', 0.007971014492753623),
#  ('k', 0.003642010163749294),
#  ('ssv', 0.0007905138339920949),
#  ('ps', 0.0007905138339920949),
#  ('ap', 0.0),
#  ('sg', 0.0),
#  ('sp', 0.0),
#  ('md', 0.0),
#  ('ka', 0.0),
#  ('dp', 0.0),
#  ('ar', 0.0),
#  ('gk', 0.0),
#  ('ag', 0.0)]

# %%
pg=nx.pagerank(g)
import operator
sorted(pg.items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('mp', 0.08899500089891275),
#  ('da', 0.0760136711853489),
#  ('hd', 0.05928704983479549),
#  ('sk', 0.05832527525845583),
#  ('ss', 0.05806012146114561),
#  ('sm', 0.05292386426607927),
#  ('a', 0.05227276527324467),
#  ('br', 0.04274607265012667),
#  ('ssv', 0.03994539813916827),
#  ('ps', 0.03994539813916827),
#  ('ak', 0.036888268169128685),
#  ('pb', 0.03531499743999905),
#  ('sp', 0.035208451094531176),
#  ('md', 0.035208451094531176),
#  ('ka', 0.035208451094531176),
#  ('dp', 0.035208451094531176),
#  ('hm', 0.03505837745053621),
#  ('ap', 0.034033157960432686),
#  ('sg', 0.034033157960432686),
#  ('as', 0.03361840534521481),
#  ('k', 0.02337601424141387),
#  ('ag', 0.021586728307710627),
#  ('ar', 0.020967041451192946),
#  ('gk', 0.01577543018936782)]

# %%
pg_alpha=nx.pagerank(g,alpha=0.85)
import operator
sorted(pg_alpha.items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('mp', 0.08899500089891275),
#  ('da', 0.0760136711853489),
#  ('hd', 0.05928704983479549),
#  ('sk', 0.05832527525845583),
#  ('ss', 0.05806012146114561),
#  ('sm', 0.05292386426607927),
#  ('a', 0.05227276527324467),
#  ('br', 0.04274607265012667),
#  ('ssv', 0.03994539813916827),
#  ('ps', 0.03994539813916827),
#  ('ak', 0.036888268169128685),
#  ('pb', 0.03531499743999905),
#  ('sp', 0.035208451094531176),
#  ('md', 0.035208451094531176),
#  ('ka', 0.035208451094531176),
#  ('dp', 0.035208451094531176),
#  ('hm', 0.03505837745053621),
#  ('ap', 0.034033157960432686),
#  ('sg', 0.034033157960432686),
#  ('as', 0.03361840534521481),
#  ('k', 0.02337601424141387),
#  ('ag', 0.021586728307710627),
#  ('ar', 0.020967041451192946),
#  ('gk', 0.01577543018936782)]
